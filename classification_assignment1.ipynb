# %%
import turicreate

# %%
house_data = turicreate.SFrame('home_data.sframe')

# %%
house_data
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %%
train_data,test_data = house_data.random_split(.8,seed=0)

# %%
def simple_linear_regression(input_feature, output):
    reg_model = turicreate.linear_regression.create(house_data,
                                                   target= 'input_feature',
                                                    features=['output'],
                                                    validation_set=None,
                                                    verbose=False                                             
                                                   )
    #print("input_feature = {} , output = {}".format(input_feature,output) )
    
#return(intercept, slope)

# %%
simple_linear_regression('sqft_living','price')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/turicreate/data_structures/sframe.py in select_columns(self, column_names)
#    3381             return SFrame(
# -> 3382                 data=[], _proxy=self.__proxy__.select_columns(selected_columns)
#    3383             )
#
# cy_sframe.pyx in turicreate._cython.cy_sframe.UnitySFrameProxy.select_columns()
#
# cy_sframe.pyx in turicreate._cython.cy_sframe.UnitySFrameProxy.select_columns()
#
# RuntimeError: Column output does not exist
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/turicreate/toolkits/_internal_utils.py in _toolkits_select_columns(dataset, columns)
#     567     try:
# --> 568         return dataset.select_columns(columns)
# ...

# %%
def simple_linear_regression(input_feature, output):
    reg_model = turicreate.linear_regression.create(house_data,
                                                    target= 'price',
                                                    features=['sqft_living'],
                                                    validation_set=None,
                                                    verbose=False                                             
                                              ) 
    print(reg_model.coeffcoefficients)
    print(input_feature)
    #print("input_feature = {} , output = {}".format(input_feature,output) )
    
#return(intercept, slope)

# %%
price = house_data['price']
sum_price= price.sum()
number_house = price.size()
